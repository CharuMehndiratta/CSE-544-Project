# %%
import json

business_data = open('/Users/charumehndiratta/Downloads/dataset/business.json')
restaurants = []

for line in business_data:
    business = json.loads(line)
    if 'Restaurants' in business['categories'] and 'Chipotle' in business['name']:
        restaurants.append(business['business_id'])

review_data = open('/Users/charumehndiratta/Downloads/dataset/review.json')
reviews = []

review_dict = {}

for line in review_data:
    review = json.loads(line)
    review_dict[review['business_id']] = {'date' : review['date'], 'stars': review['stars'], 'text': review['text'], }

# print(review_dict)
reviews = []

print 'Review done'

for restaurant in restaurants:
    if restaurant in review_dict:
        reviews.append(review_dict[restaurant])
# Out:
# Review done

# %%
reviews
# Out:
# [{'date': u'2017-04-22',
#   'stars': 2,
#   'text': u"Worst chipotle I've been to. Not friendly at all. EXTREMELY stingy on the portions. Parking lot is really hard to navigate. 3/10 would not come again"},
#  {'date': u'2015-12-17',
#   'stars': 5,
# ...

# %%
len(reviews)
# Out:
# 176

# %%
import json

business_data = open('/Users/charumehndiratta/Downloads/dataset/business.json')
restaurants = []

for line in business_data:
    business = json.loads(line)
    if 'Restaurants' in business['categories'] and 'Chipotle' in business['name']:
        restaurants.append(business['business_id'])

checkin_data = open('/Users/charumehndiratta/Downloads/dataset/checkin.json')
checkins = []

checkin_dict = {}

for line in checkin_data:
    checkin = json.loads(line)
    checkin_dict[checkin['business_id']] = {'time' : checkin['time']}

# print(review_dict)
checkins = []

print 'Review done'

for restaurant in restaurants:
    if restaurant in checkin_dict:
        checkins.append(checkin_dict[restaurant])
        
        
for key, val in checkins
# Out:
# Review done

# %%
len(checkins)
# Out:
# 176

# %%
len(restaurants)
# Out:
# 176

# %%
checkins
# Out:
# [{'time': {u'Friday': {u'15:00': 1,
#     u'16:00': 2,
#     u'17:00': 2,
#     u'18:00': 1,
#     u'19:00': 1,
#     u'1:00': 2,
#     u'23:00': 3},
#    u'Monday': {u'16:00': 2, u'17:00': 2, u'20:00': 2, u'23:00': 1},
#    u'Saturday': {u'0:00': 2,
#     u'1:00': 1,
#     u'20:00': 1,
#     u'21:00': 1,
#     u'23:00': 3},
#    u'Sunday': {u'15:00': 1, u'17:00': 1, u'22:00': 1},
#    u'Thursday': {u'16:00': 2,
#     u'18:00': 1,
#     u'21:00': 1,
#     u'22:00': 1,
#     u'23:00': 1},
#    u'Tuesday': {u'15:00': 2, u'17:00': 1, u'19:00': 1},
#    u'Wednesday': {u'0:00': 1, u'16:00': 2, u'17:00': 1, u'18:00': 1}}},
#  {'time': {u'Friday': {u'0:00': 1,
#     u'15:00': 1,
#     u'16:00': 1,
#     u'17:00': 2,
#     u'1:00': 2,
#     u'21:00': 3,
#     u'22:00': 3,
#     u'23:00': 2},
#    u'Monday': {u'0:00': 1,
#     u'16:00': 1,
#     u'17:00': 1,
#     u'21:00': 1,
#     u'22:00': 2,
#     u'23:00': 1,
#     u'2:00': 1},
#    u'Saturday': {u'0:00': 2,
#     u'15:00': 2,
# ...
